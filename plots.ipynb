# %%
import matplotlib.pyplot as plt
import pickle
import itertools

with open("results_myro.pickle","rb") as f:
    stats = pickle.load(f)

# %%
new_stats =  {}
for l in [2,4,6]:
    for wt in [0,0.2,0.6]:
        file_name = "results_top_{}".format(l)
        if wt != 0:
            file_name += "_wt_0{}.pickle".format(int(wt*10))
        else:
            file_name += ".pickle"
        algo_name = "top_{}_wt_{}".format(l, int(wt*10))
        with open(file_name, "rb") as f:
            stat = pickle.load(f)
        new_stats[algo_name] = stat

# %%
stats
# Out:
# {'sat_greedy': {(20, 0.1): <utils.Stats at 0x7f3f915d5480>,
#   (20, 0.25): <utils.Stats at 0x7f3d46aa6e60>,
#   (20, 0.4): <utils.Stats at 0x7f3d5052ba60>,
#   (50, 0.1): <utils.Stats at 0x7f3d46a4b370>,
#   (50, 0.25): <utils.Stats at 0x7f3d46a4b430>,
#   (50, 0.4): <utils.Stats at 0x7f3d46a4b550>,
#   (100, 0.1): <utils.Stats at 0x7f3d46a4b610>,
#   (100, 0.25): <utils.Stats at 0x7f3d46a4b700>,
#   (100, 0.4): <utils.Stats at 0x7f3d46a4b7f0>},
#  'sat_greedy_explore': {(20, 0.1): <utils.Stats at 0x7f3d46a4b8e0>,
#   (20, 0.25): <utils.Stats at 0x7f3d46a4bdc0>,
#   (20, 0.4): <utils.Stats at 0x7f3d46bc0c10>,
#   (50, 0.1): <utils.Stats at 0x7f3d46bc0f10>,
#   (50, 0.25): <utils.Stats at 0x7f3d46bc1000>,
#   (50, 0.4): <utils.Stats at 0x7f3d46bc10f0>,
#   (100, 0.1): <utils.Stats at 0x7f3d46bc11e0>,
#   (100, 0.25): <utils.Stats at 0x7f3d46bc2980>,
#   (100, 0.4): <utils.Stats at 0x7f3d46bc14b0>},
#  'sat_weighted': {(20, 0.1): <utils.Stats at 0x7f3d46bc1960>,
# ...

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
top_L_keys = []
for key, item in new_stats.items():
    for key_orig in item.keys():
        new_key = key + "_" + "_".join(key_orig.split("_")[:-1])
        stats[new_key] = item[key_orig]
        top_L_keys.append(new_key)

# %%
len(stats)
# Out:
# 39

# %%
list(stats.keys())
# Out:
# ['sat_greedy',
#  'sat_greedy_explore',
#  'sat_weighted',
#  'sat_weighted_explore',
#  'unsat_greedy',
#  'unsat_greedy_explore',
#  'unsat_weighted',
#  'unsat_weighted_explore',
#  'unsat_sat_greedy',
#  'unsat_sat_greedy_explore',
#  'unsat_sat_weighted',
#  'unsat_sat_weighted_explore',
#  'top_2_wt_0_sat_greedy',
#  'top_2_wt_0_unsat_greedy',
#  'top_2_wt_0_unsat_sat_greedy',
#  'top_2_wt_2_sat_greedy',
#  'top_2_wt_2_unsat_greedy',
#  'top_2_wt_2_unsat_sat_greedy',
#  'top_2_wt_6_sat_greedy',
#  'top_2_wt_6_unsat_greedy',
#  'top_2_wt_6_unsat_sat_greedy',
#  'top_4_wt_0_sat_greedy',
#  'top_4_wt_0_unsat_greedy',
#  'top_4_wt_0_unsat_sat_greedy',
#  'top_4_wt_2_sat_greedy',
#  'top_4_wt_2_unsat_greedy',
#  'top_4_wt_2_unsat_sat_greedy',
#  'top_4_wt_6_sat_greedy',
#  'top_4_wt_6_unsat_greedy',
#  'top_4_wt_6_unsat_sat_greedy',
#  'top_6_wt_0_sat_greedy',
#  'top_6_wt_0_unsat_greedy',
#  'top_6_wt_0_unsat_sat_greedy',
#  'top_6_wt_2_sat_greedy',
#  'top_6_wt_2_unsat_greedy',
# ...

# %%
n = [20, 50, 100]
rate = [0.1, 0.25, 0.4]
frac_of_errs = [0.01, 0.05, 0.1]
cases = list(itertools.product(n, rate))

# %%
self.l1_dist = l1_dist
self.absolute_correct = absolute_correct
self.is_codeword = is_codeword
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5f008aacb8d6> in <module>
# ----> 1 self.l1_dist = l1_dist
#       2 self.absolute_correct = absolute_correct
#       3 self.is_codeword = is_codeword
#
# NameError: name 'l1_dist' is not defined

# %%
colors = ['seagreen', 'seagreen', 'limegreen', 'limegreen', 'orangered', 'orangered', 'lightsalmon', 'lightsalmon', 'royalblue', 'royalblue', 'cornflowerblue', 'cornflowerblue']
edgecolors = ['seagreen','dimgrey', 'limegreen', 'dimgrey', 'orangered', 'dimgrey','lightsalmon', 'dimgrey','royalblue', 'dimgrey','cornflowerblue', 'dimgrey',]

# %%
short = []
med = []
long = []
total_count = len(rate)
for key in top_L_keys + []:
    short_l1_dist_avg = 0
    med_l1_dist_avg = 0
    long_l1_dist_avg = 0
    
    for i in rate:
        short_l1_dist_avg += stats[key][(n[0],)+(i,)].l1_dist/total_count
        med_l1_dist_avg += stats[key][(n[1],)+(i,)].l1_dist/total_count
        long_l1_dist_avg += stats[key][(n[2],)+(i,)].l1_dist/total_count

    short.append(short_l1_dist_avg/n[0]*100)
    med.append(med_l1_dist_avg/n[1]*100)
    long.append(long_l1_dist_avg/n[2]*100)

# %%
short
# Out:
# [21.166666666666668,
#  19.499999999999996,
#  20.083333333333332,
#  18.5,
#  19.083333333333332,
#  18.333333333333332,
#  19.333333333333336,
#  17.166666666666668,
#  18.916666666666668,
#  20.16666666666667,
#  18.75,
#  21.333333333333332,
#  17.583333333333336,
#  17.416666666666668,
#  16.833333333333332,
#  17.25,
#  17.583333333333336,
#  17.083333333333332,
#  32.333333333333336,
#  34.0,
#  32.58333333333333,
#  16.666666666666664,
#  17.25,
#  17.0,
#  14.416666666666666,
#  16.166666666666668,
#  16.416666666666664]

# %%
short = {}
med = {}
long = {}
total_count = len(rate)
for key in stats.keys():
    short_l1_dist_avg = 0
    med_l1_dist_avg = 0
    long_l1_dist_avg = 0
    
    for i in rate:
        short_l1_dist_avg += stats[key][(n[0],)+(i,)].l1_dist/total_count
        med_l1_dist_avg += stats[key][(n[1],)+(i,)].l1_dist/total_count
        long_l1_dist_avg += stats[key][(n[2],)+(i,)].l1_dist/total_count

    short[key] = short_l1_dist_avg/n[0]*100
    med[key] = med_l1_dist_avg/n[1]*100
    long[key] = long_l1_dist_avg/n[2]*100

# %%
plt.figure(figsize=(25, 5))
#plt.subplot(131)
plt.bar(top_L_keys, short)
# plt.subplot(132)
# plt.bar(list(stats.keys()), med_l1_dist_avg_default)
# plt.subplot(133)
# plt.bar(list(stats.keys()), long_l1_dist_avg_default)
plt.show()

# %%
plt.figure(figsize=(25, 5))
#plt.subplot(131)
plt.bar(list(stats.keys()), short)
# plt.subplot(132)
# plt.bar(list(stats.keys()), med_l1_dist_avg_default)
# plt.subplot(133)
# plt.bar(list(stats.keys()), long_l1_dist_avg_default)
plt.show()

# %%
short
# Out:
# [17.599999999999998,
#  48.133333333333326,
#  50.13333333333334,
#  52.39999999999999,
#  18.866666666666667,
#  47.53333333333333,
#  51.800000000000004,
#  50.4,
#  11.266666666666667,
#  51.53333333333333,
#  50.06666666666666,
#  51.0]

# %%
plt.figure(figsize=(25, 5))
plt.bar(list(stats.keys()), med)
plt.show()

# %%
plt.figure(figsize=(25, 5))
plt.bar(list(stats.keys()), long)

plt.show()

# %%
short
# Out:
# [14.777777777777779,
#  15.333333333333332,
#  15.0,
#  13.666666666666664,
#  14.11111111111111,
#  13.333333333333332,
#  13.555555555555555,
#  14.88888888888889,
#  11.555555555555557,
#  13.444444444444445,
#  13.444444444444446,
#  13.333333333333332]

# %%
with open("results_myro.pickle","rb") as f:
    stats = pickle.load(f)

# %%
n = [20, 50, 100]
rate = [0.1, 0.25, 0.4]

# %%
list(stats.keys())
# Out:
# ['sat_greedy',
#  'sat_greedy_explore',
#  'sat_weighted',
#  'sat_weighted_explore',
#  'unsat_greedy',
#  'unsat_greedy_explore',
#  'unsat_weighted',
#  'unsat_weighted_explore',
#  'unsat_sat_greedy',
#  'unsat_sat_greedy_explore',
#  'unsat_sat_weighted',
#  'unsat_sat_weighted_explore']

# %%
short = []
med = []
long = []
total_count = len(rate)
for key in stats.keys():
    short_l1_dist_avg = 0
    med_l1_dist_avg = 0
    long_l1_dist_avg = 0
    
    for i in rate:
        short_l1_dist_avg += stats[key][(n[0],)+(i,)].l1_dist/total_count
        med_l1_dist_avg += stats[key][(n[1],)+(i,)].l1_dist/total_count
        long_l1_dist_avg += stats[key][(n[2],)+(i,)].l1_dist/total_count

    short.append(short_l1_dist_avg/n[0]*100)
    med.append(med_l1_dist_avg/n[1]*100)
    long.append(long_l1_dist_avg/n[2]*100)

# %%
fig, ax = plt.subplots(figsize=(25, 10))

plt.bar(list(stats.keys()), med, color=colors, edgecolor=edgecolors, linewidth=4)
plt.xticks(fontsize=15)
for i in range(len(med)):
    plt.text(i,int(med[i]), str(int(med[i]))+'%', size=20)
plt.ylabel('% of bits away from solution')
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
plt.show()

# %%
plt.bar(['sat greedy', 'unsat greedy', 'unsat sat greedy'], [long[0],long[4],long[8]], color=['seagreen','orangered', 'royalblue'])
plt.ylabel('% of bits away from solution')
for i in range(3):
    plt.text(i,int([long[0],long[4],long[8]][i]), str(int([long[0],long[4],long[8]][i]))+'%', size=15, va='bottom')

# %%
plt.figure(figsize=(25, 5))
plt.bar(list(stats.keys()), med, color=colors, edgecolor=edgecolors, linewidth=4)
for i in range(len(short)):
    plt.text(i,int(med[i]), str(int(med[i]))+'%', size=20)
plt.ylabel('% of bits away from solution')
plt.show()

# %%
plt.figure(figsize=(10, 15))
plt.subplot(311)
plt.bar(['sat greedy', 'unsat greedy', 'unsat sat greedy'], [long[0],long[4],long[8]], color=['seagreen','orangered', 'royalblue'])
plt.ylabel('% of bits away from solution')
plt.title('n=100')
for i in range(3):
    plt.text(i,int([long[0],long[4],long[8]][i]), str(int([long[0],long[4],long[8]][i]))+'%', size=15, va='bottom')
    
plt.subplot(312)
plt.bar(['sat greedy', 'unsat greedy', 'unsat sat greedy'], [med[0],med[4],med[8]], color=['seagreen','orangered', 'royalblue'])
plt.ylabel('% of bits away from solution')
plt.title('n=50')
for i in range(3):
    plt.text(i,int([med[0],med[4],med[8]][i]), str(int([med[0],med[4],med[8]][i]))+'%', size=15, va='bottom')

plt.subplot(313)
plt.bar(['sat greedy', 'unsat greedy', 'unsat sat greedy'], [short[0],short[4],short[8]], color=['seagreen','orangered', 'royalblue'])
plt.ylabel('% of bits away from solution')
for i in range(3):
    plt.text(i,int([short[0],short[4],short[8]][i]), str(int([short[0],short[4],short[8]][i]))+'%', size=15, va='bottom')
plt.title('n=20')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(25, 10))

plt.bar(list(stats.keys()), short, color=colors, edgecolor=edgecolors, linewidth=4)
plt.xticks(fontsize=15)
for i in range(len(short)):
    plt.text(i,int(short[i]), str(int(short[i]))+'%', size=20)
plt.ylabel('% of bits away from solution')
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
plt.show()

# %%
plt.bar(['sat greedy', 'unsat greedy', 'unsat sat greedy'], [short[0],short[4],short[8]], color=['seagreen','orangered', 'royalblue'])
plt.ylabel('% of bits away from solution')
for i in range(3):
    plt.text(i,int([short[0],short[4],short[8]][i]), str(int([short[0],short[4],short[8]][i]))+'%', size=15, va='bottom')

# %%
from matplotlib.figure import Figure
import seaborn as sns

# %%
sns.barplot(list(stats.keys()), short)
# Out:
# C:\Users\myros\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
short_exact = []
med_exact = []
long_exact = []
total_count = len(rate)
for key in stats.keys():
    short_exact_avg = 0
    med_exact_avg = 0
    long_exact_avg = 0
    
    for i in rate:
        short_exact_avg += stats[key][(n[0],)+(i,)].is_codeword/total_count
        med_exact_avg += stats[key][(n[1],)+(i,)].is_codeword/total_count
        long_exact_avg += stats[key][(n[2],)+(i,)].is_codeword/total_count

    short_exact.append(short_exact_avg)
    med_exact.append(med_exact_avg)
    long_exact.append(long_exact_avg)

# %%
plt.figure(figsize=(25, 5))
plt.bar(list(stats.keys()), med_exact, color=colors, edgecolor=edgecolors, linewidth=4)
for i in range(len(short)):
    plt.text(i,med_exact[i], str(round(med_exact[i], 3)*100)+'%', size=20)
plt.ylabel('% of return codes that are valid codewords')
plt.show()

# %%
short = []
med = []
long = []
total_count = len(n)
for key in stats.keys():
    short_l1_dist_avg = 0
    med_l1_dist_avg = 0
    long_l1_dist_avg = 0
    
    for i in n:
        short_l1_dist_avg += (stats[key][(i,)+(rate[0],)].l1_dist/i)/total_count
        med_l1_dist_avg += (stats[key][(i,)+(rate[1],)].l1_dist/i)/total_count
        long_l1_dist_avg += (stats[key][(i,)+(rate[2],)].l1_dist/i)/total_count

    short.append(short_l1_dist_avg*100)
    med.append(med_l1_dist_avg*100)
    long.append(long_l1_dist_avg*100)

# %%
plt.figure(figsize=(35, 5))
plt.bar(list(stats.keys()), short, color=colors, edgecolor=edgecolors, linewidth=4)
for i in range(len(short)):
    plt.text(i,int(short[i]), str(int(short[i]))+'%', size=20)
plt.ylabel('% of bits away from solution')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-155-47547982d5c0> in <module>
#       1 plt.figure(figsize=(35, 5))
# ----> 2 plt.bar(list(stats.keys()), short, color=colors, edgecolor=edgecolors, linewidth=4)
#       3 for i in range(len(short)):
#       4     plt.text(i,int(short[i]), str(int(short[i]))+'%', size=20)
#       5 plt.ylabel('% of bits away from solution')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2485         x, height, width=0.8, bottom=None, *, align='center',
#    2486         data=None, **kwargs):
# -> 2487     return gca().bar(
#    2488         x, height, width=width, bottom=bottom, align=align,
#    2489         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
plt.figure(figsize=(25, 5))
plt.bar(list(stats.keys()), med, color=colors, edgecolor=edgecolors, linewidth=4)
for i in range(len(short)):
    plt.text(i,int(med[i]), str(int(med[i]))+'%', size=20)
plt.ylabel('% of bits away from solution')
plt.show()

# %%
plt.figure(figsize=(25, 5))
plt.bar(list(stats.keys()), long, color=colors, edgecolor=edgecolors, linewidth=4)
for i in range(len(short)):
    plt.text(i,int(long[i]), str(int(long[i]))+'%', size=20)
plt.ylabel('% of bits away from solution')
plt.show()

# %%
with open("results_myro.pickle","rb") as f:
    stats = pickle.load(f)

# %%
low_p = []
med_p = []
high_p = []
very_high_p = []
algos = []
total_count = len(rate)
for key, value in stats.items():
    low_p_l1_dist_avg = 0
    med_p_l1_dist_avg = 0
    high_p_l1_dist_avg = 0
    very_high_p_l1_dist_avg = 0
    algo, p = key
    if algo not in algos:
        algos.append(algo)
    
    for i in rate:
        if p == 0.1:
            low_p_l1_dist_avg += value[(50,)+(i,)].l1_dist/(total_count)
        elif p== 0.25:
            med_p_l1_dist_avg += value[(50,)+(i,)].l1_dist/(total_count)
        elif p == 0.33:
            high_p_l1_dist_avg += value[(50,)+(i,)].l1_dist/(total_count)
        elif p == 0.5:
            very_high_p_l1_dist_avg += value[(50,)+(i,)].l1_dist/(total_count)
    if p == 0.1:
        low_p.append(low_p_l1_dist_avg/50*100)
    elif p== 0.25:
        med_p.append(med_p_l1_dist_avg/50*100)
    elif p == 0.33:
        high_p.append(high_p_l1_dist_avg/50*100)
    elif p == 0.5:
        very_high_p.append(very_high_p_l1_dist_avg/50*100)

# %%
plt.figure(figsize=(20, 5))
plt.bar(algos, avg)
for i in range(len(avg)):
    plt.text(i,int(avg[i]), str(int(avg[i]))+'%', size=20)
plt.show()

# %%
for p in [low_p, med_p, high_p, very_high_p]:
    plt.figure(figsize=(20, 5))
    plt.bar(algos, p)
    for i in range(len(p)):
        plt.text(i,int(p[i]), str(int(p[i]))+'%', size=20)
    plt.ylabel('% of bits away from solution')
    plt.show()

# %%
len(med_p)
# Out:
# 6

# %%
stats[('sat_greedy_explore', 0.1)][(50,0.1)].l1_dist
# Out:
# 20.9

# %%
algos_p_vs_acc = {}
for i in range(len(algos)):
    algos_p_vs_acc[algos[i]] = ([0.05,0.1,0.25,0.33,0.5],[avg[i],low_p[i], med_p[i], high_p[i], very_high_p[i]])
    
# for algo, plot_points in algos_p_vs_acc.items():
#     plt.plot(plot_points[0], plot_points[1])
#     plt.ylabel('% error')
#     plt.xlabel('p')
#     plt.title(algo)
#     plt.show()

plt.figure(figsize=(20, 10))
plt.subplot(231)
plt.plot(algos_p_vs_acc['sat_greedy_explore'][0],algos_p_vs_acc['sat_greedy_explore'][1])
plt.ylabel('% error')
plt.xlabel('p')
plt.title('sat_greedy_explore')
plt.subplot(232)
plt.plot(algos_p_vs_acc['unsat_greedy_explore'][0],algos_p_vs_acc['unsat_greedy_explore'][1])
plt.ylabel('% error')
plt.xlabel('p')
plt.title('unsat_greedy_explore')
plt.subplot(233)
plt.plot(algos_p_vs_acc['unsat_sat_greedy_explore'][0],algos_p_vs_acc['unsat_sat_greedy_explore'][1])
plt.ylabel('% error')
plt.xlabel('p')
plt.title('unsat_sat_greedy_explore')
plt.subplot(234)
plt.plot(algos_p_vs_acc['sat_weighted_explore'][0],algos_p_vs_acc['sat_weighted_explore'][1])
plt.ylabel('% error')
plt.xlabel('p')
plt.title('sat_weighted_explore')
plt.subplot(235)
plt.plot(algos_p_vs_acc['unsat_weighted_explore'][0],algos_p_vs_acc['unsat_weighted_explore'][1])
plt.ylabel('% error')
plt.xlabel('p')
plt.title('unsat_weighted_explore')
plt.subplot(236)
plt.plot(algos_p_vs_acc['unsat_sat_weighted_explore'][0],algos_p_vs_acc['unsat_sat_weighted_explore'][1])
plt.ylabel('% error')
plt.xlabel('p')
plt.title('unsat_sat_weighted_explore')
plt.show()

# %%
with open("p_005.pickle","rb") as f:
    stats = pickle.load(f)

# %%
avg= []
for value in stats.values():
    avg.append(sum([i.l1_dist/150*100 for i in value.values()]))
# Out:
# {(50, 0.1): <utils.Stats object at 0x00000284B67F15B0>, (50, 0.25): <utils.Stats object at 0x00000284B2EAA190>, (50, 0.4): <utils.Stats object at 0x00000284B2EAA1C0>}
# {(50, 0.1): <utils.Stats object at 0x00000284B681BA90>, (50, 0.25): <utils.Stats object at 0x00000284B5025070>, (50, 0.4): <utils.Stats object at 0x00000284B50252B0>}
# {(50, 0.1): <utils.Stats object at 0x00000284B2EE1040>, (50, 0.25): <utils.Stats object at 0x00000284B2E540D0>, (50, 0.4): <utils.Stats object at 0x00000284B6ECBB20>}
# {(50, 0.1): <utils.Stats object at 0x00000284B5248640>, (50, 0.25): <utils.Stats object at 0x00000284B30F8D30>, (50, 0.4): <utils.Stats object at 0x00000284B30F8D60>}
# {(50, 0.1): <utils.Stats object at 0x00000284B30F8AC0>, (50, 0.25): <utils.Stats object at 0x00000284B30F8A30>, (50, 0.4): <utils.Stats object at 0x00000284B30F8850>}
# ...

# %%
avg
# Out:
# [33.85333333333333,
#  49.85333333333334,
#  33.85333333333333,
#  51.10666666666666,
#  34.2,
#  49.69333333333333]

# %%
with open("lambda.pickle","rb") as f:
    lam_stats = pickle.load(f)

# %%
very_low_lam =[]
low_lam = []
med_lam = []
high_lam = []
algos = []
total_count = len(rate)
for key, value in lam_stats.items():
    very_low_lam_l1_dist_avg = 0
    low_lam_l1_dist_avg = 0
    med_lam_l1_dist_avg = 0
    high_lam_l1_dist_avg = 0
    algo, lam = key
    if algo not in algos:
        algos.append(algo)
    
    for i in rate:
        if lam == 1:
            very_low_lam_l1_dist_avg += value[(50,)+(i,)].l1_dist/(total_count)
        elif lam == 2:
            low_lam_l1_dist_avg += value[(50,)+(i,)].l1_dist/(total_count)
        elif lam== 5:
            med_lam_l1_dist_avg += value[(50,)+(i,)].l1_dist/(total_count)
        elif lam == 10:
            high_lam_l1_dist_avg += value[(50,)+(i,)].l1_dist/(total_count)
    
    if lam == 1:
        very_low_lam.append(very_low_lam_l1_dist_avg/50*100)
    elif lam == 2:
        low_lam.append(low_lam_l1_dist_avg/50*100)
    elif lam == 5:
        med_lam.append(med_lam_l1_dist_avg/50*100)
    elif lam == 10:
        high_lam.append(high_lam_l1_dist_avg/50*100)

# %%
for lam in [very_low_lam, low_lam, med_lam, high_lam]:
    plt.figure(figsize=(20, 5))
    plt.bar(algos, lam)
    for i in range(len(lam)):
        plt.text(i,int(lam[i]), str(int(lam[i]))+'%', size=20)
    plt.ylabel('% of bits away from solution')
    plt.show()

# %%
algos_p_vs_acc = {}
for i in range(len(algos)):
    algos_p_vs_acc[algos[i]] = ([1,2,5,10],[very_low_lam[i],low_lam[i], med_lam[i], high_lam[i]])
    
plt.figure(figsize=(20, 10))
plt.subplot(231)
plt.plot(algos_p_vs_acc['sat_weighted'][0],algos_p_vs_acc['sat_weighted'][1])
plt.ylabel('% error')
plt.xlabel('p')
plt.title('sat_weighted')
plt.subplot(232)
plt.plot(algos_p_vs_acc['sat_weighted_explore'][0],algos_p_vs_acc['sat_weighted_explore'][1])
plt.ylabel('% error')
plt.xlabel('p')
plt.title('sat_weighted_explore')
plt.subplot(233)
plt.plot(algos_p_vs_acc['unsat_weighted'][0],algos_p_vs_acc['unsat_weighted'][1])
plt.ylabel('% error')
plt.xlabel('p')
plt.title('unsat_weighted')
plt.subplot(234)
plt.plot(algos_p_vs_acc['unsat_weighted_explore'][0],algos_p_vs_acc['unsat_weighted_explore'][1])
plt.ylabel('% error')
plt.xlabel('p')
plt.title('unsat_weighted_explore')
plt.subplot(235)
plt.plot(algos_p_vs_acc['unsat_sat_weighted'][0],algos_p_vs_acc['unsat_sat_weighted'][1])
plt.ylabel('% error')
plt.xlabel('p')
plt.title('unsat_sat_weighted')
plt.subplot(236)
plt.plot(algos_p_vs_acc['unsat_sat_weighted_explore'][0],algos_p_vs_acc['unsat_sat_weighted_explore'][1])
plt.ylabel('% error')
plt.xlabel('p')
plt.title('unsat_sat_weighted_explore')
plt.show()

# %%
algos
# Out:
# ['sat_weighted',
#  'sat_weighted_explore',
#  'unsat_weighted',
#  'unsat_weighted_explore',
#  'unsat_sat_weighted',
#  'unsat_sat_weighted_explore']

# %%
# Out:
# {'sat_greedy': {(20, 0.1): <utils.Stats at 0x7f3f915d5480>,
#   (20, 0.25): <utils.Stats at 0x7f3d46aa6e60>,
#   (20, 0.4): <utils.Stats at 0x7f3d5052ba60>,
#   (50, 0.1): <utils.Stats at 0x7f3d46a4b370>,
#   (50, 0.25): <utils.Stats at 0x7f3d46a4b430>,
#   (50, 0.4): <utils.Stats at 0x7f3d46a4b550>,
#   (100, 0.1): <utils.Stats at 0x7f3d46a4b610>,
#   (100, 0.25): <utils.Stats at 0x7f3d46a4b700>,
#   (100, 0.4): <utils.Stats at 0x7f3d46a4b7f0>},
#  'sat_greedy_explore': {(20, 0.1): <utils.Stats at 0x7f3d46a4b8e0>,
#   (20, 0.25): <utils.Stats at 0x7f3d46a4bdc0>,
#   (20, 0.4): <utils.Stats at 0x7f3d46bc0c10>,
#   (50, 0.1): <utils.Stats at 0x7f3d46bc0f10>,
#   (50, 0.25): <utils.Stats at 0x7f3d46bc1000>,
#   (50, 0.4): <utils.Stats at 0x7f3d46bc10f0>,
#   (100, 0.1): <utils.Stats at 0x7f3d46bc11e0>,
#   (100, 0.25): <utils.Stats at 0x7f3d46bc2980>,
#   (100, 0.4): <utils.Stats at 0x7f3d46bc14b0>},
#  'sat_weighted': {(20, 0.1): <utils.Stats at 0x7f3d46bc1960>,
# ...

# %%
algos_p_vs_acc = {}
for i in range(len(algos)):
    algos_p_vs_acc[algos[i]] = ([0.05,0.1,0.25,0.33,0.5],[avg[i],low_p[i], med_p[i], high_p[i], very_high_p[i]])
    
# for algo, plot_points in algos_p_vs_acc.items():
#     plt.plot(plot_points[0], plot_points[1])
#     plt.ylabel('% error')
#     plt.xlabel('p')
#     plt.title(algo)
#     plt.show()

plt.figure(figsize=(20, 10))
plt.subplot(231)
plt.plot(algos_p_vs_acc['sat_greedy_explore'][0],algos_p_vs_acc['sat_greedy_explore'][1])
plt.ylabel('% error')
plt.xlabel('p')
plt.title('sat_greedy_explore')
plt.subplot(232)
plt.plot(algos_p_vs_acc['unsat_greedy_explore'][0],algos_p_vs_acc['unsat_greedy_explore'][1])
plt.ylabel('% error')
plt.xlabel('p')
plt.title('unsat_greedy_explore')
plt.subplot(233)
plt.plot(algos_p_vs_acc['unsat_sat_greedy_explore'][0],algos_p_vs_acc['unsat_sat_greedy_explore'][1])
plt.ylabel('% error')
plt.xlabel('p')
plt.title('unsat_sat_greedy_explore')
plt.subplot(234)
plt.plot(algos_p_vs_acc['sat_weighted_explore'][0],algos_p_vs_acc['sat_weighted_explore'][1])
plt.ylabel('% error')
plt.xlabel('p')
plt.title('sat_weighted_explore')
plt.subplot(235)
plt.plot(algos_p_vs_acc['unsat_weighted_explore'][0],algos_p_vs_acc['unsat_weighted_explore'][1])
plt.ylabel('% error')
plt.xlabel('p')
plt.title('unsat_weighted_explore')
plt.subplot(236)
plt.plot(algos_p_vs_acc['unsat_sat_weighted_explore'][0],algos_p_vs_acc['unsat_sat_weighted_explore'][1])
plt.ylabel('% error')
plt.xlabel('p')
plt.title('unsat_sat_weighted_explore')
plt.show()

# %%
top_L_keys
avg_dict = {}
for key in top_L_keys:
# Out:
# {'sat_greedy': {(20, 0.1): <utils.Stats at 0x7f3f915d5480>,
#   (20, 0.25): <utils.Stats at 0x7f3d46aa6e60>,
#   (20, 0.4): <utils.Stats at 0x7f3d5052ba60>,
#   (50, 0.1): <utils.Stats at 0x7f3d46a4b370>,
#   (50, 0.25): <utils.Stats at 0x7f3d46a4b430>,
#   (50, 0.4): <utils.Stats at 0x7f3d46a4b550>,
#   (100, 0.1): <utils.Stats at 0x7f3d46a4b610>,
#   (100, 0.25): <utils.Stats at 0x7f3d46a4b700>,
#   (100, 0.4): <utils.Stats at 0x7f3d46a4b7f0>},
#  'sat_greedy_explore': {(20, 0.1): <utils.Stats at 0x7f3d46a4b8e0>,
#   (20, 0.25): <utils.Stats at 0x7f3d46a4bdc0>,
#   (20, 0.4): <utils.Stats at 0x7f3d46bc0c10>,
#   (50, 0.1): <utils.Stats at 0x7f3d46bc0f10>,
#   (50, 0.25): <utils.Stats at 0x7f3d46bc1000>,
#   (50, 0.4): <utils.Stats at 0x7f3d46bc10f0>,
#   (100, 0.1): <utils.Stats at 0x7f3d46bc11e0>,
#   (100, 0.25): <utils.Stats at 0x7f3d46bc2980>,
#   (100, 0.4): <utils.Stats at 0x7f3d46bc14b0>},
#  'sat_weighted': {(20, 0.1): <utils.Stats at 0x7f3d46bc1960>,
# ...

# %%
plt.figure(figsize=(10, 15))
plt.subplot(311)
plt.bar(['sat greedy', 'unsat greedy', 'unsat sat greedy'], [long[0],long[4],long[8]], color=['seagreen','orangered', 'royalblue'])
plt.ylabel('% of bits away from solution')
plt.title('n=100')
for i in range(3):
    plt.text(i,int([long[0],long[4],long[8]][i]), str(int([long[0],long[4],long[8]][i]))+'%', size=15, va='bottom')
    
plt.subplot(312)
plt.bar(['sat greedy', 'unsat greedy', 'unsat sat greedy'], [med[0],med[4],med[8]], color=['seagreen','orangered', 'royalblue'])
plt.ylabel('% of bits away from solution')
plt.title('n=50')
for i in range(3):
    plt.text(i,int([med[0],med[4],med[8]][i]), str(int([med[0],med[4],med[8]][i]))+'%', size=15, va='bottom')

plt.subplot(313)
plt.bar(['sat greedy', 'unsat greedy', 'unsat sat greedy'], [short[0],short[4],short[8]], color=['seagreen','orangered', 'royalblue'])
plt.ylabel('% of bits away from solution')
for i in range(3):
    plt.text(i,int([short[0],short[4],short[8]][i]), str(int([short[0],short[4],short[8]][i]))+'%', size=15, va='bottom')
plt.title('n=20')
plt.show()

# %%
top_L_keys + ["sat_greedy" ,"unsat_greedy","unsat_sat_greedy"]
# Out:
# ['top_2_wt_0_sat_greedy',
#  'top_2_wt_0_unsat_greedy',
#  'top_2_wt_0_unsat_sat_greedy',
#  'top_2_wt_2_sat_greedy',
#  'top_2_wt_2_unsat_greedy',
#  'top_2_wt_2_unsat_sat_greedy',
#  'top_2_wt_6_sat_greedy',
#  'top_2_wt_6_unsat_greedy',
#  'top_2_wt_6_unsat_sat_greedy',
#  'top_4_wt_0_sat_greedy',
#  'top_4_wt_0_unsat_greedy',
#  'top_4_wt_0_unsat_sat_greedy',
#  'top_4_wt_2_sat_greedy',
#  'top_4_wt_2_unsat_greedy',
#  'top_4_wt_2_unsat_sat_greedy',
#  'top_4_wt_6_sat_greedy',
#  'top_4_wt_6_unsat_greedy',
#  'top_4_wt_6_unsat_sat_greedy',
#  'top_6_wt_0_sat_greedy',
#  'top_6_wt_0_unsat_greedy',
#  'top_6_wt_0_unsat_sat_greedy',
#  'top_6_wt_2_sat_greedy',
#  'top_6_wt_2_unsat_greedy',
#  'top_6_wt_2_unsat_sat_greedy',
#  'top_6_wt_6_sat_greedy',
#  'top_6_wt_6_unsat_greedy',
#  'top_6_wt_6_unsat_sat_greedy',
#  'sat_greedy',
#  'unsat_greedy',
#  'unsat_sat_greedy']

# %%
wt = 0
wt_string = "wt_{}".format(wt)
keys = []
wt_keys = [key in top_L_keys if wt_string in key]

plt.figure(figsize=(10, 15))
plt.subplot(311)
plt.bar(['sat greedy', 'unsat greedy', 'unsat sat greedy'], [long[0],long[4],long[8]], color=['seagreen','orangered', 'royalblue'])
plt.ylabel('% of bits away from solution')
plt.title('n=100')
for i in range(3):
    plt.text(i,int([long[0],long[4],long[8]][i]), str(int([long[0],long[4],long[8]][i]))+'%', size=15, va='bottom')
    
plt.subplot(312)
plt.bar(['sat greedy', 'unsat greedy', 'unsat sat greedy'], [med[0],med[4],med[8]], color=['seagreen','orangered', 'royalblue'])
plt.ylabel('% of bits away from solution')
plt.title('n=50')
for i in range(3):
    plt.text(i,int([med[0],med[4],med[8]][i]), str(int([med[0],med[4],med[8]][i]))+'%', size=15, va='bottom')

plt.subplot(313)
plt.bar(['sat greedy', 'unsat greedy', 'unsat sat greedy'], [short[0],short[4],short[8]], color=['seagreen','orangered', 'royalblue'])
plt.ylabel('% of bits away from solution')
for i in range(3):
    plt.text(i,int([short[0],short[4],short[8]][i]), str(int([short[0],short[4],short[8]][i]))+'%', size=15, va='bottom')
plt.title('n=20')
plt.show()

# %%
for key in top_L_keys:
    if "wt_0" in key:
        print(key)
# Out:
# top_2_wt_0_sat_greedy
# top_2_wt_0_unsat_greedy
# top_2_wt_0_unsat_sat_greedy
# top_4_wt_0_sat_greedy
# top_4_wt_0_unsat_greedy
# top_4_wt_0_unsat_sat_greedy
# top_6_wt_0_sat_greedy
# top_6_wt_0_unsat_greedy
# top_6_wt_0_unsat_sat_greedy

# %%
fig, ax = plt.subplots(figsize=(25, 10))
extra_keys = ["sat_greedy" ,"unsat_greedy","unsat_sat_greedy"]
wt = 0
wt_string = "wt_{}".format(wt)
keys = []
wt_keys = [key for key in top_L_keys if wt_string in key]
tot_keys = wt_keys + extra_keys
short_ = [short[key] for key in tot_keys]
med_ = [med[key] for key in tot_keys]
long_ = [long[key] for key in tot_keys]
# print(wt_keys + extra_keys)
# plt.bar(tot_keys, short_, color=colors, edgecolor=edgecolors, linewidth=4)
# plt.xticks(fontsize=15)
# for i in range(len(short_)):
#     plt.text(i,int(short_[i]), str(int(short_[i]))+'%', size=20)
# plt.ylabel('% of bits away from solution')
# plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
# plt.show()

plt.figure(figsize=(50, 15))
plt.subplot(311)
plt.bar(tot_keys, long_, color=colors, edgecolor=edgecolors, linewidth=4)
plt.xticks(fontsize=15)
for i in range(len(long_)):
    plt.text(i,int(long_[i]), str(int(long_[i]))+'%', size=15, va='bottom')
plt.ylabel('% of bits away from solution')
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')

plt.title('n=100')
# for i in range(3):
#     plt.text(i,int([long[0],long[4],long[8]][i]), str(int([long[0],long[4],long[8]][i]))+'%', size=15, va='bottom')
    
plt.subplot(312)
plt.bar(tot_keys, med_, color=colors, edgecolor=edgecolors, linewidth=4)
plt.xticks(fontsize=15)
for i in range(len(med_)):
    plt.text(i,int(med_[i]), str(int(med_[i]))+'%', size=15, va='bottom')
plt.ylabel('% of bits away from solution')
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')

plt.title("n=50")

plt.subplot(313)
plt.bar(tot_keys, short_, color=colors, edgecolor=edgecolors, linewidth=4)
plt.xticks(fontsize=15)
for i in range(len(short_)):
    plt.text(i,int(short_[i]), str(int(short_[i]))+'%', size=15, va='bottom')
plt.ylabel('% of bits away from solution')
plt.title('n=20')
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')

# plt.show()
plt.savefig()

# %%
fig, ax = plt.subplots(figsize=(25, 10))
extra_keys = ["sat_greedy" ,"unsat_greedy","unsat_sat_greedy"]
wt = 2
wt_string = "wt_{}".format(wt)
keys = []
wt_keys = [key for key in top_L_keys if wt_string in key]
tot_keys = wt_keys + extra_keys
short_ = [short[key] for key in tot_keys]
med_ = [med[key] for key in tot_keys]
long_ = [long[key] for key in tot_keys]
# print(wt_keys + extra_keys)
# plt.bar(tot_keys, short_, color=colors, edgecolor=edgecolors, linewidth=4)
# plt.xticks(fontsize=15)
# for i in range(len(short_)):
#     plt.text(i,int(short_[i]), str(int(short_[i]))+'%', size=20)
# plt.ylabel('% of bits away from solution')
# plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
# plt.show()

plt.figure(figsize=(50, 15))
plt.subplot(311)
plt.bar(tot_keys, long_, color=colors, edgecolor=edgecolors, linewidth=4)
plt.xticks(fontsize=15)
for i in range(len(long_)):
    plt.text(i,int(long_[i]), str(int(long_[i]))+'%', size=15, va='bottom')
plt.ylabel('% of bits away from solution')
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')

plt.title('n=100')
# for i in range(3):
#     plt.text(i,int([long[0],long[4],long[8]][i]), str(int([long[0],long[4],long[8]][i]))+'%', size=15, va='bottom')
    
plt.subplot(312)
plt.bar(tot_keys, med_, color=colors, edgecolor=edgecolors, linewidth=4)
plt.xticks(fontsize=15)
for i in range(len(med_)):
    plt.text(i,int(med_[i]), str(int(med_[i]))+'%', size=15, va='bottom')
plt.ylabel('% of bits away from solution')
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')

plt.title("n=50")

plt.subplot(313)
plt.bar(tot_keys, short_, color=colors, edgecolor=edgecolors, linewidth=4)
plt.xticks(fontsize=15)
for i in range(len(short_)):
    plt.text(i,int(short_[i]), str(int(short_[i]))+'%', size=15, va='bottom')
plt.ylabel('% of bits away from solution')
plt.title('n=20')
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')

# plt.show()
# plt.savefig()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [54], line 53
#      50 plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
#      52 # plt.show()
# ---> 53 plt.savefig()
#
# File /opt/conda/envs/pyldpc-env/lib/python3.10/site-packages/matplotlib/pyplot.py:954, in savefig(*args, **kwargs)
#     951 @_copy_docstring_and_deprecators(Figure.savefig)
#     952 def savefig(*args, **kwargs):
#     953     fig = gcf()
# --> 954     res = fig.savefig(*args, **kwargs)
#     955     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#     956     return res
#
# TypeError: Figure.savefig() missing 1 required positional argument: 'fname'

# %%
fig, ax = plt.subplots(figsize=(25, 10))
extra_keys = ["sat_greedy" ,"unsat_greedy","unsat_sat_greedy"]
wt = 6
wt_string = "wt_{}".format(wt)
keys = []
wt_keys = [key for key in top_L_keys if wt_string in key]
tot_keys = wt_keys + extra_keys
short_ = [short[key] for key in tot_keys]
med_ = [med[key] for key in tot_keys]
long_ = [long[key] for key in tot_keys]
# print(wt_keys + extra_keys)
# plt.bar(tot_keys, short_, color=colors, edgecolor=edgecolors, linewidth=4)
# plt.xticks(fontsize=15)
# for i in range(len(short_)):
#     plt.text(i,int(short_[i]), str(int(short_[i]))+'%', size=20)
# plt.ylabel('% of bits away from solution')
# plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
# plt.show()

plt.figure(figsize=(50, 15))
plt.subplot(311)
plt.bar(tot_keys, long_, color=colors, edgecolor=edgecolors, linewidth=4)
plt.xticks(fontsize=15)
for i in range(len(long_)):
    plt.text(i,int(long_[i]), str(int(long_[i]))+'%', size=15, va='bottom')
plt.ylabel('% of bits away from solution')
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')

plt.title('n=100')
# for i in range(3):
#     plt.text(i,int([long[0],long[4],long[8]][i]), str(int([long[0],long[4],long[8]][i]))+'%', size=15, va='bottom')
    
plt.subplot(312)
plt.bar(tot_keys, med_, color=colors, edgecolor=edgecolors, linewidth=4)
plt.xticks(fontsize=15)
for i in range(len(med_)):
    plt.text(i,int(med_[i]), str(int(med_[i]))+'%', size=15, va='bottom')
plt.ylabel('% of bits away from solution')
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')

plt.title("n=50")

plt.subplot(313)
plt.bar(tot_keys, short_, color=colors, edgecolor=edgecolors, linewidth=4)
plt.xticks(fontsize=15)
for i in range(len(short_)):
    plt.text(i,int(short_[i]), str(int(short_[i]))+'%', size=15, va='bottom')
plt.ylabel('% of bits away from solution')
plt.title('n=20')
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')

# plt.show()
plt.savefig()
