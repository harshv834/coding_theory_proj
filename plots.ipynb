# %%
import matplotlib.pyplot as plt
import pickle
import itertools

with open("results.pickle","rb") as f:
    stats = pickle.load(f)

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
list(stats.keys())
# Out:
# ['sat_greedy',
#  'sat_greedy_explore',
#  'sat_weighted',
#  'sat_weighted_explore',
#  'unsat_greedy',
#  'unsat_greedy_explore',
#  'unsat_weighted',
#  'unsat_weighted_explore',
#  'unsat_sat_greedy',
#  'unsat_sat_greedy_explore',
#  'unsat_sat_weighted',
#  'unsat_sat_weighted_explore']

# %%
n = [20, 100, 1000]
rate = [0.1, 0.25, 0.4]
frac_of_errs = [0.1, 0.25, 0.4]
cases = list(itertools.product(n, rate, frac_of_errs))

# %%
self.l1_dist = l1_dist
self.absolute_correct = absolute_correct
self.is_codeword = is_codeword
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5f008aacb8d6> in <module>
# ----> 1 self.l1_dist = l1_dist
#       2 self.absolute_correct = absolute_correct
#       3 self.is_codeword = is_codeword
#
# NameError: name 'l1_dist' is not defined

# %%
short = []
med = []
long = []
total_count = len(list(itertools.product(rate, frac_of_errs)))
for key in stats.keys():
    short_l1_dist_avg = 0
    med_l1_dist_avg = 0
    long_l1_dist_avg = 0
    
    for i in list(itertools.product(rate, frac_of_errs)):
        short_l1_dist_avg += stats[key][(n[0],)+i].l1_dist/total_count
        med_l1_dist_avg += stats[key][(n[1],)+i].l1_dist/total_count
        long_l1_dist_avg += stats[key][(n[2],)+i].l1_dist/total_count

    short.append(short_l1_dist_avg/n[0]*100)
    med.append(med_l1_dist_avg/n[1]*100)
    long.append(long_l1_dist_avg/n[2]*100)

# %%
plt.figure(figsize=(25, 5))
#plt.subplot(131)
plt.bar(list(stats.keys()), short)
# plt.subplot(132)
# plt.bar(list(stats.keys()), med_l1_dist_avg_default)
# plt.subplot(133)
# plt.bar(list(stats.keys()), long_l1_dist_avg_default)
plt.show()

# %%
plt.figure(figsize=(25, 5))
plt.bar(list(stats.keys()), med)
plt.show()

# %%
plt.figure(figsize=(25, 5))
plt.bar(list(stats.keys()), long)

plt.show()

# %%
short
# Out:
# [14.777777777777779,
#  15.333333333333332,
#  15.0,
#  13.666666666666664,
#  14.11111111111111,
#  13.333333333333332,
#  13.555555555555555,
#  14.88888888888889,
#  11.555555555555557,
#  13.444444444444445,
#  13.444444444444446,
#  13.333333333333332]

# %%
import pandas as pd

# %%
x=pd.DataFrame.from_dict(stats['sat_greedy'].items())

# %%
stats
# Out:
# {'sat_greedy': {(20, 0.1, 0.1): <utils.Stats at 0x132c6f5bf40>,
#   (20, 0.1, 0.25): <utils.Stats at 0x132c6f5b640>,
#   (20, 0.1, 0.4): <utils.Stats at 0x132c6f5bfd0>,
#   (20, 0.25, 0.1): <utils.Stats at 0x132c7624970>,
#   (20, 0.25, 0.25): <utils.Stats at 0x132c7624bb0>,
#   (20, 0.25, 0.4): <utils.Stats at 0x132c7624a90>,
#   (20, 0.4, 0.1): <utils.Stats at 0x132c7624b20>,
#   (20, 0.4, 0.25): <utils.Stats at 0x132c7624b50>,
#   (20, 0.4, 0.4): <utils.Stats at 0x132c76247f0>,
#   (100, 0.1, 0.1): <utils.Stats at 0x132c7624c40>,
#   (100, 0.1, 0.25): <utils.Stats at 0x132c7624c70>,
#   (100, 0.1, 0.4): <utils.Stats at 0x132c7624cd0>,
#   (100, 0.25, 0.1): <utils.Stats at 0x132c7624d30>,
#   (100, 0.25, 0.25): <utils.Stats at 0x132c7624d60>,
#   (100, 0.25, 0.4): <utils.Stats at 0x132c7624dc0>,
#   (100, 0.4, 0.1): <utils.Stats at 0x132c7624e20>,
#   (100, 0.4, 0.25): <utils.Stats at 0x132c7624e80>,
#   (100, 0.4, 0.4): <utils.Stats at 0x132c7624ee0>,
#   (1000, 0.1, 0.1): <utils.Stats at 0x132c7624f40>,
#   (1000, 0.1, 0.25): <utils.Stats at 0x132c7624fa0>,
#   (1000, 0.1, 0.4): <utils.Stats at 0x132c7682040>,
#   (1000, 0.25, 0.1): <utils.Stats at 0x132c76820a0>,
#   (1000, 0.25, 0.25): <utils.Stats at 0x132c7682100>,
#   (1000, 0.25, 0.4): <utils.Stats at 0x132c7682160>,
#   (1000, 0.4, 0.1): <utils.Stats at 0x132c76821c0>,
#   (1000, 0.4, 0.25): <utils.Stats at 0x132c7682220>,
#   (1000, 0.4, 0.4): <utils.Stats at 0x132c7682280>},
#  'sat_greedy_explore': {(20, 0.1, 0.1): <utils.Stats at 0x132c76822e0>,
#   (20, 0.1, 0.25): <utils.Stats at 0x132c7682340>,
#   (20, 0.1, 0.4): <utils.Stats at 0x132c76823a0>,
#   (20, 0.25, 0.1): <utils.Stats at 0x132c7682400>,
#   (20, 0.25, 0.25): <utils.Stats at 0x132c7682460>,
#   (20, 0.25, 0.4): <utils.Stats at 0x132c76824c0>,
#   (20, 0.4, 0.1): <utils.Stats at 0x132c7682520>,
#   (20, 0.4, 0.25): <utils.Stats at 0x132c7682580>,
#   (20, 0.4, 0.4): <utils.Stats at 0x132c76825e0>,
#   (100, 0.1, 0.1): <utils.Stats at 0x132c7682640>,
#   (100, 0.1, 0.25): <utils.Stats at 0x132c76826a0>,
#   (100, 0.1, 0.4): <utils.Stats at 0x132c7682700>,
#   (100, 0.25, 0.1): <utils.Stats at 0x132c7682760>,
#   (100, 0.25, 0.25): <utils.Stats at 0x132c76827c0>,
#   (100, 0.25, 0.4): <utils.Stats at 0x132c7682820>,
#   (100, 0.4, 0.1): <utils.Stats at 0x132c7682880>,
#   (100, 0.4, 0.25): <utils.Stats at 0x132c76828e0>,
#   (100, 0.4, 0.4): <utils.Stats at 0x132c7682940>,
#   (1000, 0.1, 0.1): <utils.Stats at 0x132c76829a0>,
#   (1000, 0.1, 0.25): <utils.Stats at 0x132c7682a00>,
#   (1000, 0.1, 0.4): <utils.Stats at 0x132c7682a60>,
#   (1000, 0.25, 0.1): <utils.Stats at 0x132
,
#   (100, 0.4, 0.25): <utils.Stats at 0x132c76bc100>,
#   (100, 0.4, 0.4): <utils.Stats at 0x132c76bc160>,
#   (1000, 0.1, 0.1): <utils.Stats at 0x132c76bc1c0>,
#   (1000, 0.1, 0.25): <utils.Stats at 0x132c76bc220>,
#   (1000, 0.1, 0.4): <utils.Stats at 0x132c76bc280>,
#   (1000, 0.25, 0.1): <utils.Stats at 0x132c76bc2e0>,
#   (1000, 0.25, 0.25): <utils.Stats at 0x132c76bc340>,
#   (1000, 0.25, 0.4): <utils.Stats at 0x132c76bc3a0>,
#   (1000, 0.4, 0.1): <utils.Stats at 0x132c76bc400>,
#   (1000, 0.4, 0.25): <utils.Stats at 0x132c76bc460>,
#   (1000, 0.4, 0.4): <utils.Stats at 0x132c76bc4c0>},
#  'unsat_sat_greedy_explore': {(20, 0.1, 0.1): <utils.Stats at 0x132c76bc520>,
#   (20, 0.1, 0.25): <utils.Stats at 0x132c76bc580>,
#   (20, 0.1, 0.4): <utils.Stats at 0x132c76bc5e0>,
#   (20, 0.25, 0.1): <utils.Stats at 0x132c76bc640>,
#   (20, 0.25, 0.25): <utils.Stats at 0x132c76bc6a0>,
#   (20, 0.25, 0.4): <utils.Stats at 0x132c76bc700>,
#   (20, 0.4, 0.1): <utils.Stats at 0x132c76bc760>,
#   (20, 0.4, 0.25): <utils.Stats at 0x132c76bc7c0>,
#   (20, 0.4, 0.4): <utils.Stats at 0x132c76bc820>,
#   (100, 0.1, 0.1): <utils.Stats at 0x132c76bc880>,
#   (100, 0.1, 0.25): <utils.Stats at 0x132c76bc8e0>,
#   (100, 0.1, 0.4): <utils.Stats at 0x132c76bc940>,
#   (100, 0.25, 0.1): <utils.Stats at 0x132c76bc9a0>,
#   (100, 0.25, 0.25): <utils.Stats at 0x132c76bca00>,
#   (100, 0.25, 0.4): <utils.Stats at 0x132c76bca60>,
#   (100, 0.4, 0.1): <utils.Stats at 0x132c76bcac0>,
#   (100, 0.4, 0.25): <utils.Stats at 0x132c76bcb20>,
#   (100, 0.4, 0.4): <utils.Stats at 0x132c76bcb80>,
#   (1000, 0.1, 0.1): <utils.Stats at 0x132c76bcbe0>,
#   (1000, 0.1, 0.25): <utils.Stats at 0x132c76bcc40>,
#   (1000, 0.1, 0.4): <utils.Stats at 0x132c76bcca0>,
#   (1000, 0.25, 0.1): <utils.Stats at 0x132c76bcd00>,
#   (1000, 0.25, 0.25): <utils.Stats at 0x132c76bcd60>,
#   (1000, 0.25, 0.4): <utils.Stats at 0x132c76bcdc0>,
#   (1000, 0.4, 0.1): <utils.Stats at 0x132c76bce20>,
#   (1000, 0.4, 0.25): <utils.Stats at 0x132c76bce80>,
#   (1000, 0.4, 0.4): <utils.Stats at 0x132c76bcee0>},
#  'unsat_sat_weighted': {(20, 0.1, 0.1): <utils.Stats at 0x132c76bcf40>,
#   (20, 0.1, 0.25): <utils.Stats at 0x132c76bcfa0>,
#   (20, 0.1, 0.4): <utils.Stats at 0x132c76c9040>,
#   (20, 0.25, 0.1): <utils.Stats at 0x132c76c90a0>,
#   (20, 0.25, 0.25): <utils.Stats at 0x132c76c9100>,
#   (20, 0.25, 0.4): <utils.Stats at 0x132c76c9160>,
#   (20, 0.4, 0.1): <utils.Stats at 0x132c76c91c0>,
#   (20, 0.4, 0.25): <utils.Stats at 0x132c76c9220>,
#   (20, 0.4, 0.4): <utils.Stats at 0x132c76c9280>,
#   (100, 0.1, 0.1): <utils.Stats at 0x132c76c92e0>,
#   (100, 0.1, 0.25): <utils.Stats at 0x132c76c9340>,
#   (100, 0.1, 0.4): <utils.Stats at 0x132c76c93a0>,
#   (100, 0.25, 0.1): <utils.Stats at 0x132c76c9400>,
#   (100, 0.25, 0.25): <utils.Stats at 0x132c76c9460>,
#   (100, 0.25, 0.4): <utils.Stats at 0x132c76c94c0>,
#   (100, 0.4, 0.1): <utils.Stats at 0x132c76c9520>,
#   (100, 0.4, 0.25): <utils.Stats at 0x132c76c9580>,
#   (100, 0.4, 0.4): <utils.Stats at 0x132c76c95e0>,
#   (1000, 0.1, 0.1): <utils.Stats at 0x132c76c9640>,
#   (1000, 0.1, 0.25): <utils.Stats at 0x132c76c96a0>,
#   (1000, 0.1, 0.4): <utils.Stats at 0x132c76c9700>,
#   (1000, 0.25, 0.1): <utils.Stats at 0x132c76c9760>,
#   (1000, 0.25, 0.25): <utils.Stats at 0x132c76c97c0>,
#   (1000, 0.25, 0.4): <utils.Stats at 0x132c76c9820>,
#   (1000, 0.4, 0.1): <utils.Stats at 0x132c76c9880>,
#   (1000, 0.4, 0.25): <utils.Stats at 0x132c76c98e0>,
#   (1000, 0.4, 0.4): <utils.Stats at 0x132c76c9940>},
#  'unsat_sat_weighted_explore': {(20, 0.1, 0.1): <utils.Stats at 0x132c76c99a0>,
#   (20, 0.1, 0.25): <utils.Stats at 0x132c76c9a00>,
#   (20, 0.1, 0.4): <utils.Stats at 0x132c76c9a60>,
#   (20, 0.25, 0.1): <utils.Stats at 0x132c76c9ac0>,
#   (20, 0.25, 0.25): <utils.Stats at 0x132c76c9b20>,
#   (20, 0.25, 0.4): <utils.Stats at 0x132c76c9b80>,
#   (20, 0.4, 0.1): <utils.Stats at 0x132c76c9be0>,
#   (20, 0.4, 0.25): <utils.Stats at 0x132c76c9c40>,
#   (20, 0.4, 0.4): <utils.Stats at 0x132c76c9ca0>,
#   (100, 0.1, 0.1): <utils.Stats at 0x132c76c9d00>,
#   (100, 0.1, 0.25): <utils.Stats at 0x132c76c9d60>,
#   (100, 0.1, 0.4): <utils.Stats at 0x132c76c9dc0>,
#   (100, 0.25, 0.1): <utils.Stats at 0x132c76c9e20>,
#   (100, 0.25, 0.25): <utils.Stats at 0x132c76c9e80>,
#   (100, 0.25, 0.4): <utils.Stats at 0x132c76c9ee0>,
#   (100, 0.4, 0.1): <utils.Stats at 0x132c76c9f40>,
#   (100, 0.4, 0.25): <utils.Stats at 0x132c76c9fa0>,
#   (100, 0.4, 0.4): <utils.Stats at 0x132c76d4040>,
#   (1000, 0.1, 0.1): <utils.Stats at 0x132c76d40a0>,
#   (1000, 0.1, 0.25): <utils.Stats at 0x132c76d4100>,
#   (1000, 0.1, 0.4): <utils.Stats at 0x132c76d4160>,
#   (1000, 0.25, 0.1): <utils.Stats at 0x132c76d41c0>,
#   (1000, 0.25, 0.25): <utils.Stats at 0x132c76d4220>,
#   (1000, 0.25, 0.4): <utils.Stats at 0x132c76d4280>,
#   (1000, 0.4, 0.1): <utils.Stats at 0x132c76d42e0>,
#   (1000, 0.4, 0.25): <utils.Stats at 0x132c76d4340>,
#   (1000, 0.4, 0.4): <utils.Stats at 0x132c76d43a0>}}

# %%
(20,)+(1,2)
# Out:
# (20, 1, 2)
